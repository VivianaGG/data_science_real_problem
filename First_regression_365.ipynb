# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import matplotlib as plt
import seaborn as sns 
import sklearn

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
import csv

# %%
data = pd.read_csv(r'C:\\Users\\vggon\\Documents\\Data_Science_365\\Part_5_Advanced_Statistical_Methods_(Machine_Learning)\\S32_L186\\Simple_linear_regression.csv')

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
y = data['GPA']
x1 = data['SAT']

# %%
plt.scatter(x1,y)
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %% [markdown]
# Regression itself

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Sat, 25 Dec 2021   Prob (F-statistic):           7.20e-11
# Time:                        16:16:43   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0.275
fig = plt.plot(x1,yhat, lw = 3, c = 'purple', label = 'Regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
new_data = pd.read_csv(r'C:\\Users\vggon\\Documents\\Data_Science_365\\Part_5_Advanced_Statistical_Methods_(Machine_Learning)\\S33_L194\\Multiple_linear_regression.csv')

# %%
new_data
# Out:
#      SAT   GPA  Rand 1,2,3
# 0   1714  2.40           1
# 1   1664  2.52           3
# 2   1760  2.54           3
# 3   1685  2.74           3
# 4   1693  2.83           2
# ..   ...   ...         ...
# 79  1936  3.71           3
# 80  1810  3.71           1
# 81  1987  3.73           3
# 82  1962  3.76           1
# 83  2050  3.81           2
#
# [84 rows x 3 columns]

# %%
new_data.describe()
# Out:
#                SAT        GPA  Rand 1,2,3
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    2.059524
# std     104.530661   0.271617    0.855192
# min    1634.000000   2.400000    1.000000
# 25%    1772.000000   3.190000    1.000000
# 50%    1846.000000   3.380000    2.000000
# 75%    1934.000000   3.502500    3.000000
# max    2050.000000   3.810000    3.000000

# %%
y = new_data['GPA']
x1 = new_data[['SAT', 'Rand 1,2,3']]

# %%
x = sm.add_constant(x1)
result = sm.OLS(y,x).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     27.76
# Date:                Sat, 25 Dec 2021   Prob (F-statistic):           6.58e-10
# Time:                        17:53:37   Log-Likelihood:                 12.720
# No. Observations:                  84   AIC:                            -19.44
# Df Residuals:                      81   BIC:                            -12.15
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2960      0.417      0.710      0.480      -0.533       1.125
# ...

# %%
raw_data = pd.read_csv(r'C:\\Users\\vggon\\Documents\\Data_Science_365\\Part_5_Advanced_Statistical_Methods_(Machine_Learning)\\S33_L203\\dummies.csv')

# %%
raw_data
# Out:
#      SAT   GPA Attendance
# 0   1714  2.40         No
# 1   1664  2.52         No
# 2   1760  2.54         No
# 3   1685  2.74         No
# 4   1693  2.83         No
# ..   ...   ...        ...
# 79  1936  3.71        Yes
# 80  1810  3.71        Yes
# 81  1987  3.73         No
# 82  1962  3.76        Yes
# 83  2050  3.81        Yes
#
# [84 rows x 3 columns]

# %%
data = raw_data.copy()

data['Attendance'] = data['Attendance'].map({'Yes':1, 'No':0})

# %%
data
# Out:
#      SAT   GPA  Attendance
# 0   1714  2.40           0
# 1   1664  2.52           0
# 2   1760  2.54           0
# 3   1685  2.74           0
# 4   1693  2.83           0
# ..   ...   ...         ...
# 79  1936  3.71           1
# 80  1810  3.71           1
# 81  1987  3.73           0
# 82  1962  3.76           1
# 83  2050  3.81           1
#
# [84 rows x 3 columns]

# %%
data.describe()
# Out:
#                SAT        GPA  Attendance
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    0.464286
# std     104.530661   0.271617    0.501718
# min    1634.000000   2.400000    0.000000
# 25%    1772.000000   3.190000    0.000000
# 50%    1846.000000   3.380000    0.000000
# 75%    1934.000000   3.502500    1.000000
# max    2050.000000   3.810000    1.000000

# %% [markdown]
# Regression

# %%
y = data['GPA']
x1 = data[['SAT', 'Attendance']]

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):           2.19e-15
# Time:                        17:04:41   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6439      0.358      1.797      0.076      -0.069       1.357
# ...

# %%
plt.scatter(data['SAT'],y, c = data['Attendance'], cmap = 'RdYlGn_r')
yhat_no = 0.6439 + 0.0014*data['SAT']
yhat_yes = 0.8665 + 0.0014*data['SAT']
fig = plt.plot(data['SAT'], yhat_no, lw = 2, c = '#006837')
fig = plt.plot(data['SAT'], yhat_yes, lw = 2, c = '#a50026')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
x
# Out:
#     const   SAT  Attendance
# 0     1.0  1714           0
# 1     1.0  1664           0
# 2     1.0  1760           0
# 3     1.0  1685           0
# 4     1.0  1693           0
# ..    ...   ...         ...
# 79    1.0  1936           1
# 80    1.0  1810           1
# 81    1.0  1987           0
# 82    1.0  1962           1
# 83    1.0  2050           1
#
# [84 rows x 3 columns]

# %%
new_data = pd.DataFrame({'const': 1, 'SAT':[1700,1670], 'Attendance':[0,1]})
new_data = new_data[['const', 'SAT', 'Attendance']]
new_data
# Out:
#    const   SAT  Attendance
# 0      1  1700           0
# 1      1  1670           1

# %%
new_data.rename(index = {0:'Bob', 1: 'Alice'})
# Out:
#        const   SAT  Attendance
# Bob        1  1700           0
# Alice      1  1670           1

# %%
predictions = results.predict(new_data)
predictions
# Out:
# 0    3.023513
# 1    3.204163
# dtype: float64

# %%
predictionsdf = pd.DataFrame({'Predicions': predictions})
joined = new_data.join(predictionsdf)
joined
# Out:
#    const   SAT  Attendance  Predicions
# 0      1  1700           0    3.023513
# 1      1  1670           1    3.204163

# %%
joined.rename(index = {0: 'Bob', 1: 'Alice'})
# Out:
#        const   SAT  Attendance  Predicions
# Bob        1  1700           0    3.023513
# Alice      1  1670           1    3.204163

# %%
file = open(r"C:\Users\vggon\Documents\Python\distance.txt")
dist_matrix = []
for row in file:
    dist_matrix.append([int(x) for x in row.split()])
    
dist_matrix
# Out:
# [[0, 2, 3], [2, 0, 1], [3, 1, 0]]

# %%
file = open(r"C:\Users\vggon\Documents\Python\distance.txt")
dist_matrix = []
for row in file:
    dist_matrix.append(row)
    
dist_matrix
# Out:
# ['0\t2\t3\n', '2\t0\t1\n', '3\t1\t0']
